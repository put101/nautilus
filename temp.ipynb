# %%
import importlib
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from nautilus_trader.core.rust.model import PriceType, BID, AggregationSource, EXTERNAL, LAST
from nautilus_trader.model.identifiers import Venue
import os
from data_utils import *
from nautilus_trader.test_kit.providers import TestInstrumentProvider
from nautilus_trader.model.identifiers import Symbol, Venue
from nautilus_trader.model.data import Bar,BarType,BarSpecification,BarAggregation
from nautilus_trader.model.data.bar_aggregation import MINUTE,DAY

catalogPath = os.path.join(os.getcwd(), 'catalog')
catalog = ParquetDataCatalog(catalogPath)

filename = "EURUSD.csv"
csv = os.path.join(os.getcwd(), 'data', filename)
symbol = "EURUSD"
venue = Venue("SIM")
instrument = TestInstrumentProvider.default_fx_ccy(symbol, venue)
agg_src = AggregationSource(EXTERNAL)
bar_agg = BarAggregation(DAY)
price_type = PriceType(LAST)
bar_spec = BarSpecification(1, bar_agg, price_type)
bar_type = BarType(instrument.id, bar_spec, agg_src)

# %%
csv
instrument
bar_type
# Out:
# BarType(EURUSD.SIM-1-DAY-LAST-EXTERNAL)

# %%
df = load_mt5_csv_dataframe(csv)

# %%
df
# Out:
#                open     high      low    close  tick_volume  spread  \
# time
# 2000-01-03  1.00730  1.02780  1.00540  1.02460         6642      50
# 2000-01-04  1.02430  1.03400  1.02130  1.02920         7339      50
# 2000-01-05  1.02930  1.04020  1.02840  1.03260         6570      50
# 2000-01-06  1.03250  1.04150  1.02720  1.03300         7223      50
# 2000-01-07  1.03290  1.03320  1.02600  1.02980         5689      50
# ...             ...      ...      ...      ...          ...     ...
# 2023-11-22  1.09067  1.09227  1.08522  1.08882        52654       0
# 2023-11-23  1.08882  1.09304  1.08809  1.09018        21444       0
# 2023-11-24  1.08996  1.09485  1.08948  1.09362        26523       0
# 2023-11-27  1.09386  1.09590  1.09249  1.09534        30707       0
# 2023-11-28  1.09535  1.09625  1.09343  1.09474        12071       1
#
#             real_volume
# time
# 2000-01-03            0
# 2000-01-04            0
# 2000-01-05            0
# 2000-01-06            0
# ...

# %%
bars = load_df_bars(catalog, df,bar_type, instrument )

# %%
bars
# Out:
# [Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.00730,1.02780,1.00540,1.02460,6642,946857600000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02430,1.03400,1.02130,1.02920,7339,946944000000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02930,1.04020,1.02840,1.03260,6570,947030400000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03250,1.04150,1.02720,1.03300,7223,947116800000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03290,1.03320,1.02600,1.02980,5689,947203200000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02860,1.03050,1.02110,1.02510,6197,947462400000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02530,1.03410,1.02460,1.03360,6637,947548800000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03370,1.03700,1.02610,1.03080,6877,947635200000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03090,1.03160,1.02370,1.02600,6176,947721600000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02610,1.02750,1.01140,1.01220,6176,947808000000000000),
# ...

# %%
catalog.write_data([instrument])
catalog.write_data(bars)

# %%
catalog.instruments()
# Out:
# [CurrencyPair(id=EURUSD.SIM, raw_symbol=EURUSD, asset_class=FX, asset_type=SPOT, quote_currency=USD, is_inverse=False, price_precision=5, price_increment=0.00001, size_precision=0, size_increment=1, multiplier=1, lot_size=1000, margin_init=0.03, margin_maint=0.03, maker_fee=0.00002, taker_fee=0.00002, info=None)]

# %%
import importlib
import data_utils
importlib.reload(data_utils)

bar_type_raw = data_utils.bar_type_to_str(bar_type)
bar_type_raw
# Out:
# 'EURUSD.SIM-1-DAY-LAST-EXTERNAL'

# %%
bars_res:list[Bar] = catalog.bars(bar_types=[bar_type_raw])

# %%
bars_res
# Out:
# [Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.00730,1.02780,1.00540,1.02460,6642,946857600000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02430,1.03400,1.02130,1.02920,7339,946944000000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02930,1.04020,1.02840,1.03260,6570,947030400000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03250,1.04150,1.02720,1.03300,7223,947116800000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03290,1.03320,1.02600,1.02980,5689,947203200000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02860,1.03050,1.02110,1.02510,6197,947462400000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02530,1.03410,1.02460,1.03360,6637,947548800000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03370,1.03700,1.02610,1.03080,6877,947635200000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.03090,1.03160,1.02370,1.02600,6176,947721600000000000),
#  Bar(EURUSD.SIM-1-DAY-LAST-EXTERNAL,1.02610,1.02750,1.01140,1.01220,6176,947808000000000000),
# ...
